# %%
print("INTRODUCTION: For this project, I am trying to better understand the locales in Toronto to better guide future pruchases for people.")
print("To guide this, we will use a series of different data points like, schools, entertainment access, grocery stores, etc. in order to help make our decsion.")
print("People who are intersted in buying homes and realtors will be keen on this type of data.")
print("")
print("DATA: The data will be sourced from Wiki and will include info like school districts, grocery stores, shopping malls, etc.")
print("")
print("METHODOLOGY: I am using foursqaureAPI, Folium, WorkFlow, and cluster approach to do my data analysis.")
print("The libraries I am using include Pandas, Matplot, Beautiful Soup, JSON, XML, and Sckit.")
print("RESULTS: The results are very clear and do highlight important regions. As you can see, the regions of Missisuaga and Scarborough offer the most growth while York and its promixity to downtown Toronto shows the best growth out of them all. This has been successfully completed!!")
print("CONCLUSION: York is the best place to live and it's clear this project was sucessfully completed.")
